# %% [markdown]
# <a href="https://colab.research.google.com/github/Gowrish21S/DL_assignment/blob/main/RNN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, LSTM, Dense, Dropout # Import Embedding and LSTM

text = "The beautiful girl whom I met last time is very intelligent also"
# text = "The handsome boy whom I met last time is very intelligent also"

chars = sorted(list(set(text)))
vocab_size = len(chars)
char_to_index = {char: i for i, char in enumerate(chars)}
index_to_char = {i: char for i, char in enumerate(chars)}

seq_length = 5
sequences = []
labels = []

# --- Data Preparation (X and Y remain integer encoded) ---
for i in range(len(text) - seq_length):
    seq = text[i:i + seq_length]
    label = text[i + seq_length]
    sequences.append([char_to_index[char] for char in seq])
    labels.append(char_to_index[label])

# X remains integer-encoded sequences
X = np.array(sequences)
# Y is integer-encoded labels
y = np.array(labels)

# Y is converted to one-hot for the final softmax layer loss
y_one_hot = tf.one_hot(y, vocab_size)

# --- Model Parameters ---
embedding_dim = 10 # New parameter for the embedding layer
lstm_units = 64    # Increased capacity
text_len = 50      # Length of text to generate


# -----------------------------------------------------------
# --- MODIFIED MODEL ARCHITECTURE (LSTM with Embedding) ---
# -----------------------------------------------------------
model = Sequential()
# 1. Embedding Layer (NEW)
# Maps the integer input (X) into a dense, continuous vector space.
model.add(Embedding(
    input_dim=vocab_size,
    output_dim=embedding_dim,
    input_length=seq_length
))

# 2. Stacked LSTM Layer (Improved RNN cell)
# return_sequences=True is needed to stack the next recurrent layer.
model.add(LSTM(
    units=lstm_units,
    return_sequences=True,
    activation='tanh'
))
model.add(Dropout(0.2)) # Added Dropout for regularization

# 3. Final LSTM Layer
# return_sequences=False (default) as it feeds into the Dense layer.
model.add(LSTM(units=lstm_units, activation='tanh'))
model.add(Dropout(0.2)) # Added Dropout

# 4. Dense Output Layer
model.add(Dense(vocab_size, activation='softmax'))

# Compile (Loss is still categorical_crossentropy as y is one-hot)
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# Increased epochs for better learning with a deeper model
print("Training Model...")
model.fit(X, y_one_hot, epochs=200, verbose=2)
# -----------------------------------------------------------


start_seq = "The beautiful girl whom I met "
# start_seq = "The handsome boy whom I met "

generated_text = start_seq

# --- Prediction Loop (Modified for integer input) ---
print("\nGenerating Text...")
for i in range(text_len):
    # Prepare the input sequence: Use integer encoding directly (NO one-hot here)
    x = np.array([[char_to_index[char] for char in generated_text[-seq_length:]]])

    # Model predicts based on integer input
    prediction = model.predict(x, verbose=0)[0]

    # Select the character with the highest probability (greedy approach)
    next_index = np.argmax(prediction)
    next_char = index_to_char[next_index]

    generated_text += next_char

print("\nGenerated Text:")
print(generated_text)
# Out:
# Training Model...
# Epoch 1/200
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/embedding.py:97: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(
# 2/2 - 4s - 2s/step - accuracy: 0.0169 - loss: 3.0443
# Epoch 2/200
# 2/2 - 0s - 29ms/step - accuracy: 0.1186 - loss: 3.0397
# Epoch 3/200
# 2/2 - 0s - 28ms/step - accuracy: 0.1695 - loss: 3.0357
# Epoch 4/200
# 2/2 - 0s - 27ms/step - accuracy: 0.1695 - loss: 3.0300
# Epoch 5/200
# 2/2 - 0s - 27ms/step - accuracy: 0.1695 - loss: 3.0253
# Epoch 6/200
# 2/2 - 0s - 27ms/step - accuracy: 0.1864 - loss: 3.0181
# Epoch 7/200
# 2/2 - 0s - 32ms/step - accuracy: 0.1695 - loss: 3.0105
# Epoch 8/200
# 2/2 - 0s - 31ms/step - accuracy: 0.1695 - loss: 2.9999
# Epoch 9/200
# 2/2 - 0s - 33ms/step - accuracy: 0.1695 - loss: 2.9850
# Epoch 10/200
# 2/2 - 0s - 40ms/step - accuracy: 0.1864 - loss: 2.9694
# Epoch 11/200
# 2/2 - 0s - 29ms/step - accuracy: 0.1695 - loss: 2.9522
# Epoch 12/200
# 2/2 - 0s - 30ms/step - accuracy: 0.1695 - loss: 2.9214
# Epoch 13/200
# 2/2 - 0s - 33ms/step - accuracy: 0.1695 - loss: 2.8966
# Epoch 14/200
# 2/2 - 0s - 31ms/step - accuracy: 0.1695 - loss: 2.8504
# Epoch 15/200
# 2/2 - 0s - 29ms/step - accuracy: 0.1695 - loss: 2.8279
# Epoch 16/200
# 2/2 - 0s - 32ms/step - accuracy: 0.1695 - loss: 2.7751
# Epoch 17/200
# 2/2 - 0s - 30ms/step - accuracy: 0.1695 - loss: 2.7103
# Epoch 18/200
# 2/2 - 0s - 29ms/step - accuracy: 0.1695 - loss: 2.7536
# Epoch 19/200
# 2/2 - 0s - 29ms/step - accuracy: 0.1695 - loss: 2.7143
# Epoch 20/200
# 2/2 - 0s - 28ms/step - accuracy: 0.1695 - loss: 2.7305
# Epoch 21/200
# 2/2 - 0s - 28ms/step - accuracy: 0.1525 - loss: 2.7061
# Epoch 22/200
# 2/2 - 0s - 29ms/step - accuracy: 0.1695 - loss: 2.6453
# Epoch 23/200
# 2/2 - 0s - 31ms/step - accuracy: 0.1695 - loss: 2.6690
# Epoch 24/200
# 2/2 - 0s - 31ms/step - accuracy: 0.1695 - loss: 2.6670
# Epoch 25/200
# 2/2 - 0s - 35ms/step - accuracy: 0.1695 - loss: 2.6979
# Epoch 26/200
# 2/2 - 0s - 30ms/step - accuracy: 0.1864 - loss: 2.7017
# Epoch 27/200
# 2/2 - 0s - 29ms/step - accuracy: 0.1695 - loss: 2.6667
# Epoch 28/200
# 2/2 - 0s - 30ms/step - accuracy: 0.1356 - loss: 2.6922
# Epoch 29/200
# 2/2 - 0s - 28ms/step - accuracy: 0.1695 - loss: 2.6701
# Epoch 30/200
# 2/2 - 0s - 28ms/step - accuracy: 0.1695 - loss: 2.6510
# Epoch 31/200
# 2/2 - 0s - 29ms/step - accuracy: 0.1356 - loss: 2.6375
# Epoch 32/200
# 2/2 - 0s - 31ms/step - accuracy: 0.1525 - loss: 2.6281
# Epoch 33/200
# 2/2 - 0s - 30ms/step - accuracy: 0.1695 - loss: 2.6730
# Epoch 34/200
# 2/2 - 0s - 30ms/step - accuracy: 0.1695 - loss: 2.6345
# Epoch 35/200
# 2/2 - 0s - 29ms/step - accuracy: 0.1695 - loss: 2.6431
# Epoch 36/200
# 2/2 - 0s - 29ms/step - accuracy: 0.1695 - loss: 2.6228
# Epoch 37/200
# 2/2 - 0s - 28ms/step - accuracy: 0.1695 - loss: 2.6341
# Epoch 38/200
# 2/2 - 0s - 28ms/step - accuracy: 0.1695 - loss: 2.5719
# Epoch 39/200
# 2/2 - 0s - 31ms/step - accuracy: 0.1695 - loss: 2.6153
# Epoch 40/200
# 2/2 - 0s - 29ms/step - accuracy: 0.1864 - loss: 2.5750
# Epoch 41/200
# 2/2 - 0s - 29ms/step - accuracy: 0.1525 - loss: 2.5824
# Epoch 42/200
# 2/2 - 0s - 70ms/step - accuracy: 0.1695 - loss: 2.5691
# Epoch 43/200
# 2/2 - 0s - 28ms/step - accuracy: 0.1525 - loss: 2.5477
# Epoch 44/200
# 2/2 - 0s - 29ms/step - accuracy: 0.1186 - loss: 2.5887
# Epoch 45/200
# 2/2 - 0s - 28ms/step - accuracy: 0.1695 - loss: 2.5760
# Epoch 46/200
# 2/2 - 0s - 28ms/step - accuracy: 0.1525 - loss: 2.5613
# Epoch 47/200
# 2/2 - 0s - 29ms/step - accuracy: 0.1864 - loss: 2.5208
# Epoch 48/200
# 2/2 - 0s - 31ms/step - accuracy: 0.1525 - loss: 2.5691
# Epoch 49/200
# 2/2 - 0s - 29ms/step - accuracy: 0.1695 - loss: 2.5139
# Epoch 50/200
# 2/2 - 0s - 30ms/step - accuracy: 0.1864 - loss: 2.5067
# Epoch 51/200
# 2/2 - 0s - 28ms/step - accuracy: 0.1864 - loss: 2.4758
# Epoch 52/200
# 2/2 - 0s - 29ms/step - accuracy: 0.2034 - loss: 2.4988
# Epoch 53/200
# 2/2 - 0s - 69ms/step - accuracy: 0.1695 - loss: 2.4946
# Epoch 54/200
# 2/2 - 0s - 29ms/step - accuracy: 0.2034 - loss: 2.4880
# Epoch 55/200
# 2/2 - 0s - 29ms/step - accuracy: 0.2203 - loss: 2.5055
# Epoch 56/200
# 2/2 - 0s - 69ms/step - accuracy: 0.1864 - loss: 2.5289
# Epoch 57/200
# 2/2 - 0s - 28ms/step - accuracy: 0.2034 - loss: 2.4896
# Epoch 58/200
# 2/2 - 0s - 28ms/step - accuracy: 0.2373 - loss: 2.4583
# Epoch 59/200
# 2/2 - 0s - 29ms/step - accuracy: 0.2881 - loss: 2.4361
# Epoch 60/200
# 2/2 - 0s - 28ms/step - accuracy: 0.2373 - loss: 2.4796
# Epoch 61/200
# 2/2 - 0s - 29ms/step - accuracy: 0.2373 - loss: 2.3966
# Epoch 62/200
# 2/2 - 0s - 28ms/step - accuracy: 0.2203 - loss: 2.4489
# Epoch 63/200
# 2/2 - 0s - 28ms/step - accuracy: 0.2203 - loss: 2.4396
# Epoch 64/200
# 2/2 - 0s - 29ms/step - accuracy: 0.2203 - loss: 2.4496
# Epoch 65/200
# 2/2 - 0s - 27ms/step - accuracy: 0.2712 - loss: 2.3773
# Epoch 66/200
# 2/2 - 0s - 28ms/step - accuracy: 0.2542 - loss: 2.4197
# Epoch 67/200
# 2/2 - 0s - 28ms/step - accuracy: 0.2034 - loss: 2.4024
# Epoch 68/200
# 2/2 - 0s - 30ms/step - accuracy: 0.2542 - loss: 2.3733
# Epoch 69/200
# 2/2 - 0s - 29ms/step - accuracy: 0.2034 - loss: 2.4351
# Epoch 70/200
# 2/2 - 0s - 29ms/step - accuracy: 0.2712 - loss: 2.3584
# Epoch 71/200
# 2/2 - 0s - 32ms/step - accuracy: 0.2881 - loss: 2.2974
# Epoch 72/200
# 2/2 - 0s - 67ms/step - accuracy: 0.2203 - loss: 2.3482
# Epoch 73/200
# 2/2 - 0s - 30ms/step - accuracy: 0.2712 - loss: 2.3205
# Epoch 74/200
# 2/2 - 0s - 28ms/step - accuracy: 0.2542 - loss: 2.3001
# Epoch 75/200
# 2/2 - 0s - 29ms/step - accuracy: 0.2881 - loss: 2.2998
# Epoch 76/200
# 2/2 - 0s - 29ms/step - accuracy: 0.2542 - loss: 2.2820
# Epoch 77/200
# 2/2 - 0s - 29ms/step - accuracy: 0.2542 - loss: 2.3025
# Epoch 78/200
# 2/2 - 0s - 29ms/step - accuracy: 0.2881 - loss: 2.2527
# Epoch 79/200
# 2/2 - 0s - 29ms/step - accuracy: 0.2542 - loss: 2.2072
# Epoch 80/200
# 2/2 - 0s - 30ms/step - accuracy: 0.2542 - loss: 2.2375
# Epoch 81/200
# 2/2 - 0s - 30ms/step - accuracy: 0.3220 - loss: 2.2144
# Epoch 82/200
# 2/2 - 0s - 31ms/step - accuracy: 0.2712 - loss: 2.2034
# Epoch 83/200
# 2/2 - 0s - 28ms/step - accuracy: 0.2881 - loss: 2.1814
# Epoch 84/200
# 2/2 - 0s - 35ms/step - accuracy: 0.3051 - loss: 2.1391
# Epoch 85/200
# 2/2 - 0s - 30ms/step - accuracy: 0.3390 - loss: 2.1556
# Epoch 86/200
# 2/2 - 0s - 29ms/step - accuracy: 0.3051 - loss: 2.0940
# Epoch 87/200
# 2/2 - 0s - 37ms/step - accuracy: 0.3729 - loss: 2.0601
# Epoch 88/200
# 2/2 - 0s - 35ms/step - accuracy: 0.3390 - loss: 2.0689
# Epoch 89/200
# 2/2 - 0s - 28ms/step - accuracy: 0.2881 - loss: 2.1343
# Epoch 90/200
# 2/2 - 0s - 29ms/step - accuracy: 0.3390 - loss: 2.0650
# Epoch 91/200
# 2/2 - 0s - 32ms/step - accuracy: 0.2881 - loss: 2.0865
# Epoch 92/200
# 2/2 - 0s - 30ms/step - accuracy: 0.2881 - loss: 2.0386
# Epoch 93/200
# 2/2 - 0s - 29ms/step - accuracy: 0.3390 - loss: 2.0335
# Epoch 94/200
# 2/2 - 0s - 29ms/step - accuracy: 0.3729 - loss: 2.0283
# Epoch 95/200
# 2/2 - 0s - 28ms/step - accuracy: 0.3390 - loss: 1.9567
# Epoch 96/200
# 2/2 - 0s - 84ms/step - accuracy: 0.3898 - loss: 1.9671
# Epoch 97/200
# 2/2 - 0s - 44ms/step - accuracy: 0.3559 - loss: 1.8730
# Epoch 98/200
# 2/2 - 0s - 47ms/step - accuracy: 0.3729 - loss: 1.9540
# Epoch 99/200
# 2/2 - 0s - 43ms/step - accuracy: 0.3051 - loss: 2.0012
# Epoch 100/200
# 2/2 - 0s - 53ms/step - accuracy: 0.3729 - loss: 1.8766
# Epoch 101/200
# 2/2 - 0s - 40ms/step - accuracy: 0.3390 - loss: 1.9382
# Epoch 102/200
# 2/2 - 0s - 46ms/step - accuracy: 0.2712 - loss: 1.9414
# Epoch 103/200
# 2/2 - 0s - 68ms/step - accuracy: 0.3898 - loss: 1.9026
# Epoch 104/200
# 2/2 - 0s - 70ms/step - accuracy: 0.3729 - loss: 1.8377
# Epoch 105/200
# 2/2 - 0s - 70ms/step - accuracy: 0.3559 - loss: 1.8064
# Epoch 106/200
# 2/2 - 0s - 41ms/step - accuracy: 0.3729 - loss: 1.7624
# Epoch 107/200
# 2/2 - 0s - 43ms/step - accuracy: 0.3051 - loss: 1.8118
# Epoch 108/200
# 2/2 - 0s - 39ms/step - accuracy: 0.4407 - loss: 1.7657
# Epoch 109/200
# 2/2 - 0s - 81ms/step - accuracy: 0.3390 - loss: 1.8686
# Epoch 110/200
# 2/2 - 0s - 44ms/step - accuracy: 0.3220 - loss: 1.7835
# Epoch 111/200
# 2/2 - 0s - 42ms/step - accuracy: 0.3729 - loss: 1.7866
# Epoch 112/200
# 2/2 - 0s - 41ms/step - accuracy: 0.3898 - loss: 1.7870
# Epoch 113/200
# 2/2 - 0s - 48ms/step - accuracy: 0.4237 - loss: 1.7047
# Epoch 114/200
# 2/2 - 0s - 48ms/step - accuracy: 0.3898 - loss: 1.7299
# Epoch 115/200
# 2/2 - 0s - 49ms/step - accuracy: 0.3898 - loss: 1.6870
# Epoch 116/200
# 2/2 - 0s - 68ms/step - accuracy: 0.2712 - loss: 1.6954
# Epoch 117/200
# 2/2 - 0s - 35ms/step - accuracy: 0.4237 - loss: 1.6615
# Epoch 118/200
# 2/2 - 0s - 28ms/step - accuracy: 0.4237 - loss: 1.6339
# Epoch 119/200
# 2/2 - 0s - 28ms/step - accuracy: 0.4407 - loss: 1.6514
# Epoch 120/200
# 2/2 - 0s - 29ms/step - accuracy: 0.4407 - loss: 1.5869
# Epoch 121/200
# 2/2 - 0s - 71ms/step - accuracy: 0.5085 - loss: 1.5758
# Epoch 122/200
# 2/2 - 0s - 31ms/step - accuracy: 0.4746 - loss: 1.6014
# Epoch 123/200
# 2/2 - 0s - 29ms/step - accuracy: 0.4915 - loss: 1.5834
# Epoch 124/200
# 2/2 - 0s - 27ms/step - accuracy: 0.4407 - loss: 1.5614
# Epoch 125/200
# 2/2 - 0s - 27ms/step - accuracy: 0.4915 - loss: 1.5483
# Epoch 126/200
# 2/2 - 0s - 28ms/step - accuracy: 0.5085 - loss: 1.5098
# Epoch 127/200
# 2/2 - 0s - 30ms/step - accuracy: 0.4915 - loss: 1.5167
# Epoch 128/200
# 2/2 - 0s - 29ms/step - accuracy: 0.4746 - loss: 1.5168
# Epoch 129/200
# 2/2 - 0s - 32ms/step - accuracy: 0.4237 - loss: 1.4723
# Epoch 130/200
# 2/2 - 0s - 28ms/step - accuracy: 0.4746 - loss: 1.4671
# Epoch 131/200
# 2/2 - 0s - 32ms/step - accuracy: 0.5085 - loss: 1.4509
# Epoch 132/200
# 2/2 - 0s - 30ms/step - accuracy: 0.4915 - loss: 1.4628
# Epoch 133/200
# 2/2 - 0s - 29ms/step - accuracy: 0.4915 - loss: 1.4660
# Epoch 134/200
# 2/2 - 0s - 29ms/step - accuracy: 0.5593 - loss: 1.3777
# Epoch 135/200
# 2/2 - 0s - 29ms/step - accuracy: 0.4915 - loss: 1.3736
# Epoch 136/200
# 2/2 - 0s - 72ms/step - accuracy: 0.5932 - loss: 1.3586
# Epoch 137/200
# 2/2 - 0s - 30ms/step - accuracy: 0.6102 - loss: 1.4252
# Epoch 138/200
# 2/2 - 0s - 30ms/step - accuracy: 0.5254 - loss: 1.4192
# Epoch 139/200
# 2/2 - 0s - 28ms/step - accuracy: 0.5763 - loss: 1.3095
# Epoch 140/200
# 2/2 - 0s - 29ms/step - accuracy: 0.5932 - loss: 1.3042
# Epoch 141/200
# 2/2 - 0s - 28ms/step - accuracy: 0.6271 - loss: 1.2601
# Epoch 142/200
# 2/2 - 0s - 30ms/step - accuracy: 0.5593 - loss: 1.3148
# Epoch 143/200
# 2/2 - 0s - 33ms/step - accuracy: 0.5763 - loss: 1.2459
# Epoch 144/200
# 2/2 - 0s - 28ms/step - accuracy: 0.5593 - loss: 1.1990
# Epoch 145/200
# 2/2 - 0s - 40ms/step - accuracy: 0.5763 - loss: 1.2297
# Epoch 146/200
# 2/2 - 0s - 31ms/step - accuracy: 0.6610 - loss: 1.2616
# Epoch 147/200
# 2/2 - 0s - 30ms/step - accuracy: 0.6102 - loss: 1.2081
# Epoch 148/200
# 2/2 - 0s - 37ms/step - accuracy: 0.6780 - loss: 1.2407
# Epoch 149/200
# 2/2 - 0s - 67ms/step - accuracy: 0.6102 - loss: 1.1990
# Epoch 150/200
# 2/2 - 0s - 65ms/step - accuracy: 0.6441 - loss: 1.0964
# Epoch 151/200
# 2/2 - 0s - 29ms/step - accuracy: 0.6102 - loss: 1.1355
# Epoch 152/200
# 2/2 - 0s - 29ms/step - accuracy: 0.6102 - loss: 1.1216
# Epoch 153/200
# 2/2 - 0s - 30ms/step - accuracy: 0.6610 - loss: 1.1854
# Epoch 154/200
# 2/2 - 0s - 30ms/step - accuracy: 0.6780 - loss: 1.0706
# Epoch 155/200
# 2/2 - 0s - 30ms/step - accuracy: 0.6780 - loss: 1.0635
# Epoch 156/200
# 2/2 - 0s - 33ms/step - accuracy: 0.6949 - loss: 1.0433
# Epoch 157/200
# 2/2 - 0s - 32ms/step - accuracy: 0.6441 - loss: 1.1013
# Epoch 158/200
# 2/2 - 0s - 29ms/step - accuracy: 0.7119 - loss: 1.0032
# Epoch 159/200
# 2/2 - 0s - 30ms/step - accuracy: 0.6780 - loss: 1.0879
# Epoch 160/200
# 2/2 - 0s - 30ms/step - accuracy: 0.7458 - loss: 0.9493
# Epoch 161/200
# 2/2 - 0s - 31ms/step - accuracy: 0.7119 - loss: 1.0328
# Epoch 162/200
# 2/2 - 0s - 29ms/step - accuracy: 0.7288 - loss: 1.0057
# Epoch 163/200
# 2/2 - 0s - 28ms/step - accuracy: 0.7119 - loss: 0.9237
# Epoch 164/200
# 2/2 - 0s - 31ms/step - accuracy: 0.7458 - loss: 0.9689
# Epoch 165/200
# 2/2 - 0s - 69ms/step - accuracy: 0.6949 - loss: 0.9477
# Epoch 166/200
# 2/2 - 0s - 30ms/step - accuracy: 0.7458 - loss: 0.9666
# Epoch 167/200
# 2/2 - 0s - 28ms/step - accuracy: 0.6780 - loss: 0.9518
# Epoch 168/200
# 2/2 - 0s - 30ms/step - accuracy: 0.6949 - loss: 0.9072
# Epoch 169/200
# 2/2 - 0s - 32ms/step - accuracy: 0.7288 - loss: 0.8971
# Epoch 170/200
# 2/2 - 0s - 30ms/step - accuracy: 0.7288 - loss: 0.8095
# Epoch 171/200
# 2/2 - 0s - 29ms/step - accuracy: 0.8136 - loss: 0.8206
# Epoch 172/200
# 2/2 - 0s - 30ms/step - accuracy: 0.8136 - loss: 0.8529
# Epoch 173/200
# 2/2 - 0s - 29ms/step - accuracy: 0.7627 - loss: 0.8181
# Epoch 174/200
# 2/2 - 0s - 28ms/step - accuracy: 0.7288 - loss: 0.9360
# Epoch 175/200
# 2/2 - 0s - 28ms/step - accuracy: 0.6780 - loss: 0.9123
# Epoch 176/200
# 2/2 - 0s - 28ms/step - accuracy: 0.7966 - loss: 0.8118
# Epoch 177/200
# 2/2 - 0s - 29ms/step - accuracy: 0.6780 - loss: 0.9332
# Epoch 178/200
# 2/2 - 0s - 27ms/step - accuracy: 0.7119 - loss: 0.7987
# Epoch 179/200
# 2/2 - 0s - 28ms/step - accuracy: 0.7458 - loss: 0.8069
# Epoch 180/200
# 2/2 - 0s - 70ms/step - accuracy: 0.7119 - loss: 0.8291
# Epoch 181/200
# 2/2 - 0s - 29ms/step - accuracy: 0.7288 - loss: 0.8720
# Epoch 182/200
# 2/2 - 0s - 29ms/step - accuracy: 0.7458 - loss: 0.8166
# Epoch 183/200
# 2/2 - 0s - 30ms/step - accuracy: 0.7627 - loss: 0.7944
# Epoch 184/200
# 2/2 - 0s - 28ms/step - accuracy: 0.7458 - loss: 0.7918
# Epoch 185/200
# 2/2 - 0s - 29ms/step - accuracy: 0.7119 - loss: 0.8400
# Epoch 186/200
# 2/2 - 0s - 29ms/step - accuracy: 0.7797 - loss: 0.7488
# Epoch 187/200
# 2/2 - 0s - 28ms/step - accuracy: 0.7797 - loss: 0.7453
# Epoch 188/200
# 2/2 - 0s - 28ms/step - accuracy: 0.6780 - loss: 0.7874
# Epoch 189/200
# 2/2 - 0s - 29ms/step - accuracy: 0.7288 - loss: 0.7364
# Epoch 190/200
# 2/2 - 0s - 28ms/step - accuracy: 0.7288 - loss: 0.7664
# Epoch 191/200
# 2/2 - 0s - 29ms/step - accuracy: 0.7797 - loss: 0.7402
# Epoch 192/200
# 2/2 - 0s - 28ms/step - accuracy: 0.7966 - loss: 0.6663
# Epoch 193/200
# 2/2 - 0s - 29ms/step - accuracy: 0.7458 - loss: 0.7729
# Epoch 194/200
# 2/2 - 0s - 29ms/step - accuracy: 0.7966 - loss: 0.6877
# Epoch 195/200
# 2/2 - 0s - 36ms/step - accuracy: 0.7458 - loss: 0.7071
# Epoch 196/200
# 2/2 - 0s - 31ms/step - accuracy: 0.7966 - loss: 0.6652
# Epoch 197/200
# 2/2 - 0s - 29ms/step - accuracy: 0.8305 - loss: 0.6338
# Epoch 198/200
# 2/2 - 0s - 28ms/step - accuracy: 0.8305 - loss: 0.6846
# Epoch 199/200
# 2/2 - 0s - 29ms/step - accuracy: 0.7797 - loss: 0.6889
# Epoch 200/200
# 2/2 - 0s - 29ms/step - accuracy: 0.7458 - loss: 0.6822
#
# Generating Text...
#
# Generated Text:
# The beautiful girl whom I met eauo firl gnnle grtu gnsl  nnle grtu gnsl  nnle gr
